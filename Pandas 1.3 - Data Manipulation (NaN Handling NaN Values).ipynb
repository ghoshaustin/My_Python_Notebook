# %% [markdown]
#    Content: 1. Working with NaN
#             2. Handling NaN Values

# %%
import pandas as pd
import numpy as np

# Create the DataFrame
data = {
    'Name': ['Bidhan', 'John', 'Alex', 'Bishowjith', 'Michel', 'Jackson'],
    'Age': [35, 38, np.nan, 40, 38, 37],
    'Salary': [90000, 85000, 87000, np.nan, 86000, 89000]
}

df = pd.DataFrame(data)
df
# Out:
#          Name   Age   Salary
# 0      Bidhan  35.0  90000.0
# 1        John  38.0  85000.0
# 2        Alex   NaN  87000.0
# 3  Bishowjith  40.0      NaN
# 4      Michel  38.0  86000.0
# 5     Jackson  37.0  89000.0

# %%
df.dtypes
# Out:
# Name       object
# Age       float64
# Salary    float64
# dtype: object

# %%
# Convert columns to nullable integer type
df['Age'] = df['Age'].astype('Int64')
df['Salary'] = df['Salary'].astype('Int64')
df
# Out:
#          Name   Age  Salary
# 0      Bidhan    35   90000
# 1        John    38   85000
# 2        Alex  <NA>   87000
# 3  Bishowjith    40    <NA>
# 4      Michel    38   86000
# 5     Jackson    37   89000

# %%
df.dtypes
# Out:
# Name      object
# Age        Int64
# Salary     Int64
# dtype: object

# %%
df.head(6)
# Out:
#          Name   Age  Salary
# 0      Bidhan    35   90000
# 1        John    38   85000
# 2        Alex  <NA>   87000
# 3  Bishowjith    40    <NA>
# 4      Michel    38   86000
# 5     Jackson    37   89000

# %%
#checking with isnull().sum()
df.isnull()
# Out:
#     Name    Age  Salary
# 0  False  False   False
# 1  False  False   False
# 2  False   True   False
# 3  False  False    True
# 4  False  False   False
# 5  False  False   False

# %%
df.isnull().sum()
# Out:
# Name      0
# Age       1
# Salary    1
# dtype: int64

# %%
#checking with notnull().sum()
df.notnull().sum()
# Out:
# Name      6
# Age       5
# Salary    5
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    6 non-null      object
#  1   Age     5 non-null      Int64
#  2   Salary  5 non-null      Int64
# dtypes: Int64(2), object(1)
# memory usage: 288.0+ bytes

# %%
df
# Out:
#          Name   Age  Salary
# 0      Bidhan    35   90000
# 1        John    38   85000
# 2        Alex  <NA>   87000
# 3  Bishowjith    40    <NA>
# 4      Michel    38   86000
# 5     Jackson    37   89000

# %% [markdown]
# # Handling NaN Values

# %%
df.isnull().sum()
# Out:
# Name      0
# Age       1
# Salary    1
# dtype: int64

# %%
df1 = df.copy()  #copying df as df1 with null values

# %%
df1.fillna(0, inplace=True)

# %%
df1.isnull().sum()
# Out:
# Name      0
# Age       0
# Salary    0
# dtype: int64

# %%
df1.head()
# Out:
#          Name  Age  Salary
# 0      Bidhan   35   90000
# 1        John   38   85000
# 2        Alex    0   87000
# 3  Bishowjith   40       0
# 4      Michel   38   86000

# %%
df1['Age'] = df1['Age'].replace(0, 35)
df1['Salary'] = df1['Salary'].replace(0, 35000)
df1
# Out:
#          Name  Age  Salary
# 0      Bidhan   35   90000
# 1        John   38   85000
# 2        Alex   35   87000
# 3  Bishowjith   40   35000
# 4      Michel   38   86000
# 5     Jackson   37   89000

# %%
df2 = df.copy()     #copying df as df2 with null values
df2
# Out:
#          Name   Age  Salary
# 0      Bidhan    35   90000
# 1        John    38   85000
# 2        Alex  <NA>   87000
# 3  Bishowjith    40    <NA>
# 4      Michel    38   86000
# 5     Jackson    37   89000

# %%
df2.fillna(0, inplace=True)
df2
# Out:
#          Name  Age  Salary
# 0      Bidhan   35   90000
# 1        John   38   85000
# 2        Alex    0   87000
# 3  Bishowjith   40       0
# 4      Michel   38   86000
# 5     Jackson   37   89000

# %%
# Forward Fill and backwordfill (Fill with the forward for forward fill and previous value for backword fill):
df2['Age'] = df2['Age'].replace(0, method='ffill')
df2['Salary'] = df2['Salary'].replace(0, method='bfill')
df2
# Out:
# C:\Users\johnb\AppData\Local\Temp\ipykernel_26940\3146144126.py:2: FutureWarning: The 'method' keyword in Series.replace is deprecated and will be removed in a future version.
#   df2['Age'] = df2['Age'].replace(0, method='ffill')
# C:\Users\johnb\AppData\Local\Temp\ipykernel_26940\3146144126.py:3: FutureWarning: The 'method' keyword in Series.replace is deprecated and will be removed in a future version.
#   df2['Salary'] = df2['Salary'].replace(0, method='bfill')
#          Name  Age  Salary
# 0      Bidhan   35   90000
# 1        John   38   85000
# 2        Alex   38   87000
# 3  Bishowjith   40   86000
# 4      Michel   38   86000
# 5     Jackson   37   89000

# %%
df3 = df.copy()     #copying df as df3 with null values
df3
# Out:
#          Name   Age  Salary
# 0      Bidhan    35   90000
# 1        John    38   85000
# 2        Alex  <NA>   87000
# 3  Bishowjith    40    <NA>
# 4      Michel    38   86000
# 5     Jackson    37   89000

# %%
df3.fillna(
{
    'Age' : 40,
    'Salary': 85000
})
# Out:
#          Name  Age  Salary
# 0      Bidhan   35   90000
# 1        John   38   85000
# 2        Alex   40   87000
# 3  Bishowjith   40   85000
# 4      Michel   38   86000
# 5     Jackson   37   89000

# %%
df4 = df.copy()     #copying df as df2 with null values
df4
# Out:
#          Name   Age  Salary
# 0      Bidhan    35   90000
# 1        John    38   85000
# 2        Alex  <NA>   87000
# 3  Bishowjith    40    <NA>
# 4      Michel    38   86000
# 5     Jackson    37   89000

# %%
df4.dropna(how='any')
# Out:
#       Name  Age  Salary
# 0   Bidhan   35   90000
# 1     John   38   85000
# 4   Michel   38   86000
# 5  Jackson   37   89000

# %%
df5 = df.copy()     #copying df as df2 with null values
df5
# Out:
#          Name   Age  Salary
# 0      Bidhan    35   90000
# 1        John    38   85000
# 2        Alex  <NA>   87000
# 3  Bishowjith    40    <NA>
# 4      Michel    38   86000
# 5     Jackson    37   89000

# %%
# Fill NaN with the mean and median of the column

median_value = df5['Age'].median()
df5['Age'] = df5['Age'].fillna(median_value)

mean_value = df5['Salary'].mean()
df5['Salary'] = df5['Salary'].fillna(mean_value)
df5
# Out:
#          Name  Age  Salary
# 0      Bidhan   35   90000
# 1        John   38   85000
# 2        Alex   38   87000
# 3  Bishowjith   40   87400
# 4      Michel   38   86000
# 5     Jackson   37   89000
